# %% [markdown]
# <a href="https://colab.research.google.com/github/imamsohel/Machine-Learning-Linear-Regression/blob/main/Assignment_06_Encoding_in_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/supershops.csv')

# %%
df.head(2)
# Out:
#    Marketing Spend  Administration  Transport   Area     Profit
# 0        114523.61       136897.80  471784.10  Dhaka  192261.83
# 1        162597.70       151377.59  443898.53    Ctg  191792.06

# %%
df.isnull().sum() # Transport column has a null value
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df.dtypes
# Out:
# Marketing Spend    float64
# Administration     float64
# Transport          float64
# Area                object
# Profit             float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Marketing Spend  50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Transport        49 non-null     float64
#  3   Area             50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#        Marketing Spend  Administration      Transport         Profit
# count        50.000000       50.000000      49.000000      50.000000
# mean      73721.615600   121344.639600  215331.732449  112012.639200
# std       45902.256482    28017.802755  119665.391550   40306.180338
# min           0.000000    51283.140000       0.000000   14681.400000
# 25%       39936.370000   103730.875000  134050.070000   90138.902500
# 50%       73051.080000   122699.795000  214634.810000  107978.190000
# 75%      101602.800000   144842.180000  299737.290000  139765.977500
# max      165349.200000   182645.560000  471784.100000  192261.830000

# %% [markdown]
# # Measures of Central Tendency

# %%
import seaborn as sns
sns.histplot(df['Profit']) #Histogram for Frequency or counting frequency for categorical data.

# %%
# z score with python

# %%
df['Marketing Spend'].mean()
# Out:
# 73721.6156

# %%
df['Marketing Spend'].median()
# Out:
# 73051.08

# %%
df['Transport'].mean()
# Out:
# 215331.7324489796

# %%
df['Transport'].median()
# Out:
# 214634.81

# %%
df.isnull().head()
# Out:
#    Marketing Spend  Administration  Transport   Area  Profit
# 0            False           False      False  False   False
# 1            False           False      False  False   False
# 2            False           False      False  False   False
# 3            False           False      False  False   False
# 4            False           False      False  False   False

# %%
df.Transport = df.Transport.fillna(df['Transport'].median())

# %%
df.head().sample(5)
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df1 = df.copy()

# %%
df2 = df.copy()

# %%
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()
df6 = df.copy()

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %% [markdown]
# # Replace

# %%
df.Area.unique()
# Out:
# array(['Dhaka', 'Ctg', 'Rangpur'], dtype=object)

# %%
df.Area = df.Area.replace(['Dhaka', 'Ctg', 'Rangpur'] , [0,2,4])

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     0  192261.83
# 1        162597.70       151377.59  443898.53     2  191792.06
# 2        153441.51       101145.55  407934.54     4  191050.39
# 3        144372.41       118671.85  383199.62     0  182901.99
# 4        142107.34        91391.77  366168.42     4  166187.94

# %% [markdown]
# # Encoding

# %% [markdown]
# # Label Encoder ()

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
#https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html

from sklearn.preprocessing import LabelEncoder #Encode target labels with value between 0 and n_classes-1.

le = LabelEncoder()

# %%
df1.Area = le.fit_transform(df1['Area'])

# %%
df1.head().sample(5) # label encoding according to alphabatical order, if repeat, it will taken into account the second
#alphabet
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 4        142107.34        91391.77  366168.42     2  166187.94
# 2        153441.51       101145.55  407934.54     2  191050.39
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 3        144372.41       118671.85  383199.62     1  182901.99

# %%
total_column = df2.columns

# %%
total_column
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Area', 'Profit'], dtype='object')

# %%
total_column=list(total_column) #converting total column into list for using next for loop.
total_column
# Out:
# ['Marketing Spend', 'Administration', 'Transport', 'Area', 'Profit']

# %%
np.number
# Out:
# numpy.number

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
import warnings as wr
wr.filterwarnings('ignore')

for col in total_column:
    if df2[col].dtype == np.number: # if column value contains numeric and categorical data and i want 
    #only convert categorical data into label encoder, then we have to write this way.
        continue
    
    df2[col] = le.fit_transform(df2[col])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
for col in df3.columns:
    if is_numeric_dtype(df3[col]): # another way to convert catergorical is_numeric_dtype#
        continue
    
    df3[col] = le.fit_transform(df3[col])

# %%
df3.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10     1  192261.83
# 1        162597.70       151377.59  443898.53     0  191792.06
# 2        153441.51       101145.55  407934.54     2  191050.39
# 3        144372.41       118671.85  383199.62     1  182901.99
# 4        142107.34        91391.77  366168.42     2  166187.94

# %% [markdown]
# # One Hot Encoder

# %%
df4=df5.copy()
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
dummy = pd.get_dummies(df4['Area'])

# %%
dummy.head().sample(5)
# Out:
#    Ctg  Dhaka  Rangpur
# 3    0      1        0
# 0    0      1        0
# 4    0      0        1
# 1    1      0        0
# 2    0      0        1

# %%
df4.Area.head()
# Out:
# 0      Dhaka
# 1        Ctg
# 2    Rangpur
# 3      Dhaka
# 4    Rangpur
# Name: Area, dtype: object

# %%
df4.drop('Area', axis='columns', inplace=True)

# %%
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit
# 0        114523.61       136897.80  471784.10  192261.83
# 1        162597.70       151377.59  443898.53  191792.06
# 2        153441.51       101145.55  407934.54  191050.39
# 3        144372.41       118671.85  383199.62  182901.99
# 4        142107.34        91391.77  366168.42  166187.94

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# # Dummy trap is used to?
# ### These are variables that we create specifically for regression analysis that take on one of two values: zero or one.
# * A dummy variable is a binary variable that indicates whether a separate categorical variable takes on a specific value.
# * Dummy Variables: Numeric variables used in regression analysis to represent categorical data that can only take on one of two values: zero or one.

# %%
dummy1 = pd.get_dummies(df5['Area'],drop_first=True, prefix='Dummy')

# %%
dummy1.head()
# Out:
#    Dummy_Dhaka  Dummy_Rangpur
# 0            1              0
# 1            0              0
# 2            0              1
# 3            1              0
# 4            0              1

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df5 = pd.concat([df4, dummy1] , axis=1) # concatenation or joining two data frame.

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Dummy_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83            1
# 1        162597.70       151377.59  443898.53  191792.06            0
# 2        153441.51       101145.55  407934.54  191050.39            0
# 3        144372.41       118671.85  383199.62  182901.99            1
# 4        142107.34        91391.77  366168.42  166187.94            0
#
#    Dummy_Rangpur
# 0              0
# 1              0
# 2              1
# 3              0
# 4              1

# %%
df11 = df5[['Transport']]

# %%
df11.head()
# Out:
#    Transport
# 0  471784.10
# 1  443898.53
# 2  407934.54
# 3  383199.62
# 4  366168.42

# %%
df5 = pd.concat([df4, df11] , axis=1) #concatenation or joining two data frame.#

# %%
df5.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Transport
# 0        114523.61       136897.80  471784.10  192261.83  471784.10
# 1        162597.70       151377.59  443898.53  191792.06  443898.53
# 2        153441.51       101145.55  407934.54  191050.39  407934.54
# 3        144372.41       118671.85  383199.62  182901.99  383199.62
# 4        142107.34        91391.77  366168.42  166187.94  366168.42

# %%
df6.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df7 = df6.copy()
df8 = df6.copy()
df9 = df6.copy()
df10 = df6.copy()

# %% [markdown]
# # One hot encoding using loop

# %%
columns = ['Area']

for col in columns:
    one_hot = pd.get_dummies(df6[col],drop_first=True, prefix='Area')
    new_df6 = pd.concat([df6 , one_hot], axis=1).drop(col,axis=1)

# %%
new_df6.head()
# Out:
#    Marketing Spend  Administration  Transport     Profit  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10  192261.83           1
# 1        162597.70       151377.59  443898.53  191792.06           0
# 2        153441.51       101145.55  407934.54  191050.39           0
# 3        144372.41       118671.85  383199.62  182901.99           1
# 4        142107.34        91391.77  366168.42  166187.94           0
#
#    Area_Rangpur
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1

# %%
columns = ['Area']

for col in columns:
    one_hot = pd.get_dummies(df6[col],drop_first=True, prefix='Area')
    df6 = pd.concat([df6 , one_hot], axis=1)

# %%
df6.head() # still area included
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit  Area_Dhaka  \
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83           1
# 1        162597.70       151377.59  443898.53      Ctg  191792.06           0
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39           0
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99           1
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94           0
#
#    Area_Rangpur
# 0             0
# 1             0
# 2             1
# 3             0
# 4             1

# %% [markdown]
# # Ordinal Encoder

# %%
city = df7.Area.unique()
city = ['Dhaka', 'Ctg', 'Rangpur']

# %%
df7.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordi = OrdinalEncoder(categories=[city]) # note ordinal encoder arguments are  not same as we used 
#preprocessing method before.

# %%
ordi
# Out:
# OrdinalEncoder(categories=[['Dhaka', 'Ctg', 'Rangpur']])

# %%
encoded_values = ordi.fit_transform(df7[['Area']])
encoded_values
# Out:
# array([[0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [1.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [2.],
#        [0.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [1.],
#        [2.],
#        [1.],
#        [0.],
#        [1.],
#        [0.],
#        [2.],
#        [1.],
#        [0.],
#        [1.]])

# %%
encoded = pd.DataFrame(encoded_values , columns=['encoded_values'])

# %%
encoded.head()
# Out:
#    encoded_values
# 0             0.0
# 1             1.0
# 2             2.0
# 3             0.0
# 4             2.0

# %%
df7['Area'] = encoded['encoded_values']

# %%
df7.head()
# Out:
#    Marketing Spend  Administration  Transport  Area     Profit
# 0        114523.61       136897.80  471784.10   0.0  192261.83
# 1        162597.70       151377.59  443898.53   1.0  191792.06
# 2        153441.51       101145.55  407934.54   2.0  191050.39
# 3        144372.41       118671.85  383199.62   0.0  182901.99
# 4        142107.34        91391.77  366168.42   2.0  166187.94
